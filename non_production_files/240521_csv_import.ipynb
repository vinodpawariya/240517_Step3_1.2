# %%
import pandas as pd

df = pd.read_csv("240521_DB_test.csv", encoding = 'utf-8')

display(df)
# Out:
#    物件No.        物件名    カテゴリー           住所              最寄駅①              最寄駅②  \
# 0      1   ノース　プリムラ   賃貸アパート   東京都あきる野市伊奈  ＪＲ五日市線/武蔵増戸駅\r\n      ＪＲ五日市線/武蔵引田駅
# 1      2  サンハイツナカヅカ  賃貸マンション  東京都あきる野市秋川３    ＪＲ五日市線/秋川駅\r\n  ＪＲ五日市線/武蔵引田駅\r\n
#
#           最寄駅③  駅徒歩①  駅徒歩② 駅徒歩③  ...  敷金     礼金   間取り    専有面積 外観＜URL＞  \
# 0            -     5    24    -  ...   -  6.5万円  1LDK  44.18㎡       -
# 1  ＪＲ五日市線/東秋留駅    10    22   38  ...   -      -  3LDK  53.51㎡       -
#
#   間取り図＜URL＞ 詳細<URL>         緯度         経度 定期借家
# 0         -       -  35.537863  139.59511    可
# 1         -       -  35.560000  139.60000   不可
#
# [2 rows x 25 columns]
